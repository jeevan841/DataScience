# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevan841/DataScience/blob/main/microsoft_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#this is the course on the data science repo from microsoft on github

# %%
url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
import requests
words = requests.get(url).content.decode("utf-8")
print(words[:1000])
# Out:
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.
